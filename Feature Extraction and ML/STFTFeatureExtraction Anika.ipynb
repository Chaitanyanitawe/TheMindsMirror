# %%
import pandas as pd
import numpy as np
import os

folder_path = '/content/drive/My Drive/eeg data'
file_list = os.listdir(folder_path)
files = [f for f in file_list if f.endswith('.csv')]
final_df_list = []

st_marks = ['start zero.png', 'start one.png', 'start two.jpg', 'start three.jpg', 'start four.jpg',
            'start five.jpg', 'start six.jpg', 'start seven.jpg', 'start eight.jpg', 'start nine.jpg',
            'start animal.jpg']
end_marks = ['end zero.png', 'end one.png', 'end two.jpg', 'end three.jpg', 'end four.jpg',
             'end five.jpg', 'end six.jpg', 'end seven.jpg', 'end eight.jpg', 'end nine.jpg',
             'end animal.jpg']

labels = {mark: i for i, mark in enumerate(st_marks)}

# Parameters for time slicing
window_size = 100
step_size = 50

def segment_and_label_data(df, start_marks, end_marks, labels_map):
    segments = []
    for start, end in zip(start_marks, end_marks):
        start_idx = df[df['Output1'] == start].index
        end_idx = df[df['Output1'] == end].index
        for i, j in zip(start_idx, end_idx):
            print(f"Start index: {i}, End index: {j}")  # Print start and end indices
            segment = df.iloc[i+1:j].copy()  # Exclude start and end markers
            print(f"Extracted segment between {i} and {j} with length {len(segment)}")  # Print segment length
            segment['label'] = labels[start]
            segments.append(segment)

    return pd.concat(segments, ignore_index=True) if segments else pd.DataFrame()

def time_slice(segment, window_size, step_size):
    sliced_segments = []
    for start in range(0, len(segment) - window_size + 1, step_size):
        end = start + window_size
        sliced_segment = segment.iloc[start:end].copy()
        if len(sliced_segment) == window_size:
            sliced_segments.append(sliced_segment)
    return sliced_segments

for file in files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    df.columns = ['Output1', 'Output2', 'Output3', 'Output4', 'var1', 'var2', 'var3', 'var4']

    df = df.iloc[:, :4]

    # Segment and label the data
    labeled_df = segment_and_label_data(df, st_marks, end_marks, labels)
    final_segments = []

    # Apply time slicing to each labeled segment
    for label in labeled_df['label'].unique():
        label_df = labeled_df[labeled_df['label'] == label]
        sliced_segments = time_slice(label_df, window_size, step_size)
        final_segments.extend(sliced_segments)

    # Combine all sliced segments for the current file
    file_segments_df = pd.concat(final_segments, ignore_index=True)
    final_df_list.append(file_segments_df)

final_df = pd.concat(final_df_list, ignore_index=True)


final_df.to_csv('/content/drive/My Drive/eeg data/augmented_data.csv', index=False)

print("Data augmentation complete. Augmented data saved to 'augmented_data.csv'")
# Out:
# Start index: 18831, End index: 20112
# Extracted segment between 18831 and 20112 with length 1280
# Start index: 16909, End index: 18190
# Extracted segment between 16909 and 18190 with length 1280
# Start index: 5761, End index: 6914
# Extracted segment between 5761 and 6914 with length 1152
# Start index: 3455, End index: 4992
# Extracted segment between 3455 and 4992 with length 1536
# Start index: 9477, End index: 10758
# Extracted segment between 9477 and 10758 with length 1280
# Start index: 11352, End index: 12552
# Extracted segment between 11352 and 12552 with length 1199
# Start index: 22666, End index: 23956
# Extracted segment between 22666 and 23956 with length 1289
# Start index: 7555, End index: 8836
# Extracted segment between 7555 and 8836 with length 1280
# Start index: 15041, End index: 16268
# Extracted segment between 15041 and 16268 with length 1226
# Start index: 13193, End index: 14474
# Extracted segment between 13193 and 14474 with length 1280
# Start index: 20737, End index: 21906
# Extracted segment between 20737 and 21906 with length 1168
# Start index: 21651, End index: 22932
# Extracted segment between 21651 and 22932 with length 1280
# Start index: 14219, End index: 15500
# Extracted segment between 14219 and 15500 with length 1280
# Start index: 5840, End index: 7044
# Extracted segment between 5840 and 7044 with length 1203
# Start index: 2047, End index: 3328
# Extracted segment between 2047 and 3328 with length 1280
# Start index: 19857, End index: 21138
# Extracted segment between 19857 and 21138 with length 1280
# Start index: 10503, End index: 11784
# Extracted segment between 10503 and 11784 with length 1280
# Start index: 16141, End index: 17422
# Extracted segment between 16141 and 17422 with length 1280
# Start index: 8453, End index: 9734
# Extracted segment between 8453 and 9734 with length 1280
# Start index: 12382, End index: 13578
# Extracted segment between 12382 and 13578 with length 1195
# Start index: 4097, End index: 5378
# Extracted segment between 4097 and 5378 with length 1280
# Start index: 18063, End index: 19344
# Extracted segment between 18063 and 19344 with length 1280
# Start index: 18960, End index: 20242
# Extracted segment between 18960 and 20242 with length 1281
# Start index: 17167, End index: 18448
# Extracted segment between 17167 and 18448 with length 1280
# Start index: 4353, End index: 5634
# Extracted segment between 4353 and 5634 with length 1280
# Start index: 20840, End index: 22036
# Extracted segment between 20840 and 22036 with length 1195
# Start index: 2431, End index: 3584
# Extracted segment between 2431 and 3584 with length 1152
# Start index: 13579, End index: 14860
# Extracted segment between 13579 and 14860 with length 1280
# Start index: 15373, End index: 16654
# Extracted segment between 15373 and 16654 with length 1280
# Start index: 8069, End index: 9350
# Extracted segment between 8069 and 9350 with length 1280
# Start index: 11785, End index: 13066
# Extracted segment between 11785 and 13066 with length 1280
# Start index: 9863, End index: 11144
# Extracted segment between 9863 and 11144 with length 1280
# Start index: 6147, End index: 7428
# Extracted segment between 6147 and 7428 with length 1280
# Start index: 13437, End index: 14602
# Extracted segment between 13437 and 14602 with length 1164
# Start index: 15627, End index: 16908
# Extracted segment between 15627 and 16908 with length 1280
# Start index: 6915, End index: 8196
# Extracted segment between 6915 and 8196 with length 1280
# Start index: 17549, End index: 18830
# Extracted segment between 17549 and 18830 with length 1280
# Start index: 19599, End index: 20880
# Extracted segment between 19599 and 20880 with length 1280
# Start index: 24169, End index: 25364
# Extracted segment between 24169 and 25364 with length 1194
# Start index: 21777, End index: 23058
# Extracted segment between 21777 and 23058 with length 1280
# Start index: 4865, End index: 6146
# Extracted segment between 4865 and 6146 with length 1280
# Start index: 11264, End index: 12424
# Extracted segment between 11264 and 12424 with length 1159
# Start index: 9093, End index: 10374
# Extracted segment between 9093 and 10374 with length 1280
# Start index: 2559, End index: 3840
# Extracted segment between 2559 and 3840 with length 1280
# Start index: 12297, End index: 13578
# Extracted segment between 12297 and 13578 with length 1280
# Start index: 8009, End index: 9222
# Extracted segment between 8009 and 9222 with length 1212
# Start index: 22212, End index: 23444
# Extracted segment between 22212 and 23444 with length 1231
# Start index: 14219, End index: 15500
# Extracted segment between 14219 and 15500 with length 1280
# Start index: 2175, End index: 3456
# Extracted segment between 2175 and 3456 with length 1280
# Start index: 20241, End index: 21522
# Extracted segment between 20241 and 21522 with length 1280
# Start index: 18063, End index: 19344
# Extracted segment between 18063 and 19344 with length 1280
# Start index: 16141, End index: 17422
# Extracted segment between 16141 and 17422 with length 1280
# Start index: 10119, End index: 11400
# Extracted segment between 10119 and 11400 with length 1280
# Start index: 4097, End index: 5378
# Extracted segment between 4097 and 5378 with length 1280
# Start index: 6019, End index: 7300
# Extracted segment between 6019 and 7300 with length 1280
# Start index: 12169, End index: 13450
# Extracted segment between 12169 and 13450 with length 1280
# Start index: 21523, End index: 22804
# Extracted segment between 21523 and 22804 with length 1280
# Start index: 2279, End index: 3584
# Extracted segment between 2279 and 3584 with length 1304
# Start index: 4225, End index: 5506
# Extracted segment between 4225 and 5506 with length 1280
# Start index: 8325, End index: 9606
# Extracted segment between 8325 and 9606 with length 1280
# Start index: 17807, End index: 19088
# Extracted segment between 17807 and 19088 with length 1280
# Start index: 10247, End index: 11400
# Extracted segment between 10247 and 11400 with length 1152
# Start index: 15885, End index: 17166
# Extracted segment between 15885 and 17166 with length 1280
# Start index: 14091, End index: 15244
# Extracted segment between 14091 and 15244 with length 1152
# Start index: 19601, End index: 20882
# Extracted segment between 19601 and 20882 with length 1280
# Start index: 6403, End index: 7428
# Extracted segment between 6403 and 7428 with length 1024
# Start index: 9735, End index: 11016
# Extracted segment between 9735 and 11016 with length 1280
# Start index: 2012, End index: 3200
# Extracted segment between 2012 and 3200 with length 1187
# Start index: 21395, End index: 22676
# Extracted segment between 21395 and 22676 with length 1280
# Start index: 17679, End index: 18960
# Extracted segment between 17679 and 18960 with length 1280
# Start index: 13451, End index: 14732
# Extracted segment between 13451 and 14732 with length 1280
# Start index: 3969, End index: 5250
# Extracted segment between 3969 and 5250 with length 1280
# Start index: 7941, End index: 9094
# Extracted segment between 7941 and 9094 with length 1152
# Start index: 19473, End index: 20754
# Extracted segment between 19473 and 20754 with length 1280
# Start index: 15484, End index: 16654
# Extracted segment between 15484 and 16654 with length 1169
# Start index: 5891, End index: 7172
# Extracted segment between 5891 and 7172 with length 1280
# Start index: 11657, End index: 12938
# Extracted segment between 11657 and 12938 with length 1280
# Start index: 2175, End index: 3456
# Extracted segment between 2175 and 3456 with length 1280
# Start index: 14347, End index: 15628
# Extracted segment between 14347 and 15628 with length 1280
# Start index: 20241, End index: 21522
# Extracted segment between 20241 and 21522 with length 1280
# Start index: 22291, End index: 23572
# Extracted segment between 22291 and 23572 with length 1280
# Start index: 8069, End index: 9350
# Extracted segment between 8069 and 9350 with length 1280
# Start index: 10247, End index: 11528
# Extracted segment between 10247 and 11528 with length 1280
# Start index: 4097, End index: 5378
# Extracted segment between 4097 and 5378 with length 1280
# Start index: 6147, End index: 7428
# Extracted segment between 6147 and 7428 with length 1280
# Start index: 12297, End index: 13578
# Extracted segment between 12297 and 13578 with length 1280
# Start index: 18447, End index: 19600
# Extracted segment between 18447 and 19600 with length 1152
# Start index: 16397, End index: 17678
# Extracted segment between 16397 and 17678 with length 1280
# Start index: 8453, End index: 9734
# Extracted segment between 8453 and 9734 with length 1280
# Start index: 16896, End index: 18062
# Extracted segment between 16896 and 18062 with length 1165
# Start index: 12681, End index: 13962
# Extracted segment between 12681 and 13962 with length 1280
# Start index: 21265, End index: 22546
# Extracted segment between 21265 and 22546 with length 1280
# Start index: 2303, End index: 3584
# Extracted segment between 2303 and 3584 with length 1280
# Start index: 10503, End index: 11784
# Extracted segment between 10503 and 11784 with length 1280
# Start index: 4353, End index: 5634
# Extracted segment between 4353 and 5634 with length 1280
# Start index: 23315, End index: 24596
# Extracted segment between 23315 and 24596 with length 1280
# Start index: 14603, End index: 15884
# Extracted segment between 14603 and 15884 with length 1280
# Start index: 6342, End index: 7556
# Extracted segment between 6342 and 7556 with length 1213
# Start index: 18959, End index: 20240
# Extracted segment between 18959 and 20240 with length 1280
# Start index: 15885, End index: 17166
# Extracted segment between 15885 and 17166 with length 1280
# Start index: 9863, End index: 11144
# Extracted segment between 9863 and 11144 with length 1280
# Start index: 20060, End index: 21266
# Extracted segment between 20060 and 21266 with length 1205
# Start index: 6147, End index: 7428
# Extracted segment between 6147 and 7428 with length 1280
# Start index: 2431, End index: 3712
# Extracted segment between 2431 and 3712 with length 1280
# Start index: 17935, End index: 19344
# Extracted segment between 17935 and 19344 with length 1408
# Start index: 13835, End index: 15116
# Extracted segment between 13835 and 15116 with length 1280
# Start index: 8066, End index: 9222
# Extracted segment between 8066 and 9222 with length 1155
# Start index: 4353, End index: 5634
# Extracted segment between 4353 and 5634 with length 1280
# Start index: 22163, End index: 23444
# Extracted segment between 22163 and 23444 with length 1280
# Start index: 11785, End index: 13066
# Extracted segment between 11785 and 13066 with length 1280
# Start index: 8711, End index: 9992
# Extracted segment between 8711 and 9992 with length 1280
# Start index: 14093, End index: 15374
# Extracted segment between 14093 and 15374 with length 1280
# Start index: 6789, End index: 8070
# Extracted segment between 6789 and 8070 with length 1280
# Start index: 10505, End index: 11786
# Extracted segment between 10505 and 11786 with length 1280
# Start index: 3073, End index: 4354
# Extracted segment between 3073 and 4354 with length 1280
# Start index: 16101, End index: 17296
# Extracted segment between 16101 and 17296 with length 1194
# Start index: 20115, End index: 21396
# Extracted segment between 20115 and 21396 with length 1280
# Start index: 1279, End index: 2432
# Extracted segment between 1279 and 2432 with length 1152
# Start index: 12427, End index: 13580
# Extracted segment between 12427 and 13580 with length 1152
# Start index: 18065, End index: 19218
# Extracted segment between 18065 and 19218 with length 1152
# Start index: 4959, End index: 6148
# Extracted segment between 4959 and 6148 with length 1188
# Start index: 7299, End index: 8580
# Extracted segment between 7299 and 8580 with length 1280
# Start index: 14919, End index: 16140
# Extracted segment between 14919 and 16140 with length 1220
# Start index: 3397, End index: 4608
# Extracted segment between 3397 and 4608 with length 1210
# Start index: 9221, End index: 10502
# Extracted segment between 9221 and 10502 with length 1280
# Start index: 12986, End index: 14218
# Extracted segment between 12986 and 14218 with length 1231
# Start index: 18703, End index: 19984
# Extracted segment between 18703 and 19984 with length 1280
# Start index: 5249, End index: 6530
# Extracted segment between 5249 and 6530 with length 1280
# Start index: 11143, End index: 12424
# Extracted segment between 11143 and 12424 with length 1280
# Start index: 20497, End index: 21778
# Extracted segment between 20497 and 21778 with length 1280
# Start index: 22419, End index: 23700
# Extracted segment between 22419 and 23700 with length 1280
# Start index: 16762, End index: 18062
# Extracted segment between 16762 and 18062 with length 1299
# Start index: 2559, End index: 3840
# Extracted segment between 2559 and 3840 with length 1280
# Start index: 15501, End index: 16782
# Extracted segment between 15501 and 16782 with length 1280
# Start index: 17295, End index: 18576
# Extracted segment between 17295 and 18576 with length 1280
# Start index: 8069, End index: 9350
# Extracted segment between 8069 and 9350 with length 1280
# Start index: 6147, End index: 7428
# Extracted segment between 6147 and 7428 with length 1280
# Start index: 19217, End index: 20498
# Extracted segment between 19217 and 20498 with length 1280
# Start index: 9863, End index: 11144
# Extracted segment between 9863 and 11144 with length 1280
# Start index: 4353, End index: 5634
# Extracted segment between 4353 and 5634 with length 1280
# Start index: 11750, End index: 12938
# Extracted segment between 11750 and 12938 with length 1187
# Start index: 21115, End index: 22420
# Extracted segment between 21115 and 22420 with length 1304
# Start index: 13579, End index: 14860
# Extracted segment between 13579 and 14860 with length 1280
# Start index: 8323, End index: 9604
# Extracted segment between 8323 and 9604 with length 1280
# Start index: 6650, End index: 7810
# Extracted segment between 6650 and 7810 with length 1159
# Start index: 15755, End index: 17036
# Extracted segment between 15755 and 17036 with length 1280
# Start index: 13833, End index: 15114
# Extracted segment between 13833 and 15114 with length 1280
# Start index: 17677, End index: 18958
# Extracted segment between 17677 and 18958 with length 1280
# Start index: 12039, End index: 13320
# Extracted segment between 12039 and 13320 with length 1280
# Start index: 23443, End index: 24724
# Extracted segment between 23443 and 24724 with length 1280
# Start index: 4506, End index: 5888
# Extracted segment between 4506 and 5888 with length 1381
# Start index: 19568, End index: 20752
# Extracted segment between 19568 and 20752 with length 1183
# Start index: 10245, End index: 11526
# Extracted segment between 10245 and 11526 with length 1280
# Start index: 21521, End index: 22802
# Extracted segment between 21521 and 22802 with length 1280
# Start index: 9863, End index: 11144
# Extracted segment between 9863 and 11144 with length 1280
# Start index: 5827, End index: 6532
# Extracted segment between 5827 and 6532 with length 704
# Start index: 14068, End index: 14348
# Extracted segment between 14068 and 14348 with length 279
# Start index: 3969, End index: 5634
# Extracted segment between 3969 and 5634 with length 1664
# Start index: 2303, End index: 3328
# Extracted segment between 2303 and 3328 with length 1024
# Start index: 18191, End index: 19472
# Extracted segment between 18191 and 19472 with length 1280
# Start index: 14605, End index: 17678
# Extracted segment between 14605 and 17678 with length 3072
# Start index: 21267, End index: 23444
# Extracted segment between 21267 and 23444 with length 2176
# Start index: 12425, End index: 13322
# Extracted segment between 12425 and 13322 with length 896
# Start index: 20113, End index: 21010
# Extracted segment between 20113 and 21010 with length 896
# Start index: 7941, End index: 9350
# Extracted segment between 7941 and 9350 with length 1408
# Start index: 3585, End index: 4866
# Extracted segment between 3585 and 4866 with length 1280
# Start index: 1791, End index: 3072
# Extracted segment between 1791 and 3072 with length 1280
# Start index: 7557, End index: 8838
# Extracted segment between 7557 and 8838 with length 1280
# Start index: 14968, End index: 16142
# Extracted segment between 14968 and 16142 with length 1173
# Start index: 9351, End index: 10632
# Extracted segment between 9351 and 10632 with length 1280
# Start index: 13195, End index: 14476
# Extracted segment between 13195 and 14476 with length 1280
# Start index: 20371, End index: 21524
# Extracted segment between 20371 and 21524 with length 1152
# Start index: 16655, End index: 17936
# Extracted segment between 16655 and 17936 with length 1280
# Start index: 18449, End index: 19730
# Extracted segment between 18449 and 19730 with length 1280
# Start index: 11273, End index: 12554
# Extracted segment between 11273 and 12554 with length 1280
# Start index: 5507, End index: 6788
# Extracted segment between 5507 and 6788 with length 1280
# Start index: 18321, End index: 19602
# Extracted segment between 18321 and 19602 with length 1280
# Start index: 10889, End index: 12042
# Extracted segment between 10889 and 12042 with length 1152
# Start index: 5379, End index: 6660
# Extracted segment between 5379 and 6660 with length 1280
# Start index: 1791, End index: 3072
# Extracted segment between 1791 and 3072 with length 1280
# Start index: 9209, End index: 10376
# Extracted segment between 9209 and 10376 with length 1166
# Start index: 12683, End index: 13964
# Extracted segment between 12683 and 13964 with length 1280
# Start index: 14605, End index: 15886
# Extracted segment between 14605 and 15886 with length 1280
# Start index: 3585, End index: 4866
# Extracted segment between 3585 and 4866 with length 1280
# Start index: 7301, End index: 8582
# Extracted segment between 7301 and 8582 with length 1280
# Start index: 16527, End index: 17808
# Extracted segment between 16527 and 17808 with length 1280
# Start index: 20115, End index: 21396
# Extracted segment between 20115 and 21396 with length 1280
# Start index: 19017, End index: 20242
# Extracted segment between 19017 and 20242 with length 1224
# Start index: 20883, End index: 22164
# Extracted segment between 20883 and 22164 with length 1280
# Start index: 2037, End index: 3200
# Extracted segment between 2037 and 3200 with length 1162
# Start index: 9735, End index: 11016
# Extracted segment between 9735 and 11016 with length 1280
# Start index: 11529, End index: 12810
# Extracted segment between 11529 and 12810 with length 1280
# Start index: 12939, End index: 14732
# Extracted segment between 12939 and 14732 with length 1792
# Start index: 6019, End index: 7300
# Extracted segment between 6019 and 7300 with length 1280
# Start index: 15245, End index: 16526
# Extracted segment between 15245 and 16526 with length 1280
# Start index: 7941, End index: 9222
# Extracted segment between 7941 and 9222 with length 1280
# Start index: 4037, End index: 5250
# Extracted segment between 4037 and 5250 with length 1212
# Start index: 17167, End index: 18448
# Extracted segment between 17167 and 18448 with length 1280
# Data augmentation complete. Augmented data saved to 'augmented_data.csv'

# %%
from scipy.signal import stft,welch
file_path = '/content/drive/My Drive/eeg data/augmented_data.csv'
augmented_data = pd.read_csv(file_path)
fs = 256  # Sampling rate
nperseg = 256
noverlap = 128
from scipy.stats import kurtosis,skew


def preprocess_eeg(eeg_epoch):
    eeg_epoch = eeg_epoch.astype(np.float64)  # Convert to float64
    eeg_epoch = (eeg_epoch - np.mean(eeg_epoch)) / np.std(eeg_epoch)
    return eeg_epoch
def extract_features(eeg_epoch,fs,nperseg,noverlap):
    try:
        f, t, Zxx = stft(eeg_epoch, fs=fs, nperseg=nperseg, noverlap=noverlap)
    except ValueError as e:
        print(f"ValueError: {e}")
        return None

    magnitude = np.abs(Zxx)

    mean_magnitude = np.mean(magnitude, axis=1)
    var_magnitude = np.var(magnitude, axis=1)
    kurtosis_magnitude = kurtosis(magnitude, axis=1)


    features = np.concatenate((mean_magnitude, var_magnitude, kurtosis_magnitude))

    return features

# %%
features = []
labels = []
expected_feature_shape = (387,)

for label in augmented_data['label'].unique():
    segments = augmented_data[augmented_data['label'] == label]

    for i, (_, segment) in enumerate(segments.groupby((segments.index // len(df)))):

            eeg_epoch = segment[['Output1', 'Output2', 'Output3', 'Output4']].values.T.flatten()
            eeg_epoch = preprocess_eeg(eeg_epoch)
            feat = extract_features(eeg_epoch,fs,nperseg,noverlap)
            if feat is None:
              continue

            # Check and ensure feat has a consistent shape
            if feat.shape != expected_feature_shape:
              print(f"Skipping segment {i} for label {label}: Inconsistent feature shape ({feat.shape} != {expected_feature_shape})")
              continue
            features.append(feat)
            labels.append(label)



features = np.array(features)
labels = np.array(labels)

print("Features shape:", features.shape)
print("Labels shape:", labels.shape)
# Out:
# /usr/local/lib/python3.10/dist-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 220, using nperseg = 220
#   warnings.warn('nperseg = {0:d} is greater than input length '
# Skipping segment 12 for label 0: Inconsistent feature shape ((333,) != (387,))
# Features shape: (217, 387)
# Labels shape: (217,)

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

sc= StandardScaler()
features_scaled = sc.fit_transform(features)


n_components = 50
pca = PCA(n_components=n_components)

pca.fit(features_scaled)

features_pca = pca.transform(features_scaled)

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(features_pca, labels, test_size=0.2, random_state=42)


sc= StandardScaler()
X_train_scaled = sc.fit_transform(X_train)
X_test_scaled = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import classification_report,accuracy_score



svm = SVC()

# Define the parameter grid to search through
param_grid = {
    'C': [0.1, 1, 10, 100],  # Regularization parameter
    'gamma': ['scale', 'auto', 0.1, 0.01],  # Kernel coefficient
    'kernel': ['linear', 'rbf']  # Kernel type
}

# Perform Grid Search with cross-validation
grid_search = GridSearchCV(estimator=svm, param_grid=param_grid, cv=5, scoring='accuracy')
grid_search.fit(features_pca, labels)

# Print the best parameters and best score
print("Best parameters found:", grid_search.best_params_)
print("Best cross-validation accuracy:", grid_search.best_score_)

# Evaluate the best model on your test set
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Best parameters found: {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
# Best cross-validation accuracy: 0.11543340380549683
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         3
#            1       0.50      0.33      0.40         3
#            2       0.20      0.50      0.29         2
#            3       0.20      0.25      0.22         4
#            4       0.29      0.67      0.40         3
#            5       0.00      0.00      0.00         5
#            6       0.60      0.60      0.60         5
#            7       0.43      0.60      0.50         5
#            8       0.00      0.00      0.00         3
#            9       1.00      0.57      0.73         7
#           10       1.00      0.25      0.40         4
#
#     accuracy                           0.36        44
#    macro avg       0.38      0.34      0.32        44
# weighted avg       0.45      0.36      0.36        44
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()


# Define the parameter grid to search through
param_grid_knn = {
    'n_neighbors': [3, 5, 7, 10],  # Number of neighbors to consider
    'weights': ['uniform', 'distance'],  # Weight function used in prediction
    'metric': ['euclidean', 'manhattan']  # Distance metric
}

# Perform Grid Search with cross-validation
grid_search_knn = GridSearchCV(estimator=knn, param_grid=param_grid_knn, cv=5, scoring='accuracy')
grid_search_knn.fit(features_pca, labels)

# Print the best parameters and best score
print("Best parameters found for KNN:", grid_search_knn.best_params_)
print("Best cross-validation accuracy for KNN:", grid_search_knn.best_score_)

# Evaluate the best KNN model on your test set
best_knn = grid_search_knn.best_estimator_
y_pred_knn = best_knn.predict(X_test)
print("KNN Classification Report:")
print(classification_report(y_test, y_pred_knn))
# Out:
# Best parameters found for KNN: {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'uniform'}
# Best cross-validation accuracy for KNN: 0.11553911205073994
# KNN Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.17      0.67      0.27         3
#            1       0.25      0.67      0.36         3
#            2       0.25      1.00      0.40         2
#            3       0.33      0.25      0.29         4
#            4       0.33      0.33      0.33         3
#            5       0.50      0.20      0.29         5
#            6       0.50      0.20      0.29         5
#            7       1.00      0.20      0.33         5
#            8       0.33      0.33      0.33         3
#            9       1.00      0.29      0.44         7
#           10       0.00      0.00      0.00         4
#
#     accuracy                           0.32        44
#    macro avg       0.42      0.38      0.30        44
# weighted avg       0.50      0.32      0.31        44
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
